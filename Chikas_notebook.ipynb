# %%
#import dependencies
import pandas as pd 
from sqlalchemy import create_engine

# %%
#store Train CSV into a dataframe
Train=pd.read_csv("Resources/Train-1542865627584.csv")

# %%
#store Inpatient CSV into a dataframe
Train_Inpatient=pd.read_csv("Resources/Train_Inpatientdata-1542865627584.csv")
Train_Inpatient.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt  ... ClmDiagnosisCode_7  ClmDiagnosisCode_8  \
# 0            NaN  2009-04-12  ...               2724               19889
# 1            NaN  2009-08-31  ...                NaN                 NaN
# ...

# %%
Train_Outpatient=pd.read_csv("Resources/Train_Outpatientdata-1542865627584.csv")
Train_Outpatient.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11002  CLM624349   2009-10-11  2009-10-11  PRV56011
# 1  BENE11003  CLM189947   2009-02-12  2009-02-12  PRV57610
# 2  BENE11003  CLM438021   2009-06-27  2009-06-27  PRV57595
# 3  BENE11004  CLM121801   2009-01-06  2009-01-06  PRV56011
# 4  BENE11004  CLM150998   2009-01-22  2009-01-22  PRV56011
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY326117                NaN
# 1                      80          PHY362868                NaN
# 2                      10          PHY328821                NaN
# 3                      40          PHY334319                NaN
# 4                     200          PHY403831                NaN
#
#   OtherPhysician ClmDiagnosisCode_1  ... ClmDiagnosisCode_9  \
# 0            NaN              78943  ...                NaN
# 1            NaN               6115  ...                NaN
# ...

# %%
Train_Beneficiary=pd.read_csv("Resources/Train_Beneficiarydata-1542865627584.csv")
Train_Beneficiary.head()
# Out:
#       BeneID         DOB  DOD  Gender  Race RenalDiseaseIndicator  State  \
# 0  BENE11001  1943-01-01  NaN       1     1                     0     39
# 1  BENE11002  1936-09-01  NaN       2     1                     0     39
# 2  BENE11003  1936-08-01  NaN       1     1                     0     52
# 3  BENE11004  1922-07-01  NaN       1     1                     0     39
# 4  BENE11005  1935-09-01  NaN       1     1                     0     24
#
#    County  NoOfMonths_PartACov  NoOfMonths_PartBCov  ...  \
# 0     230                   12                   12  ...
# 1     280                   12                   12  ...
# 2     590                   12                   12  ...
# 3     270                   12                   12  ...
# 4     680                   12                   12  ...
#
#    ChronicCond_Depression  ChronicCond_Diabetes  ChronicCond_IschemicHeart  \
# 0                       1                     1                          1
# ...

# %% [markdown]
# Create new dataframe with select columns

# %%
Train_df = Train[['Provider', 'PotentialFraud']]
Train_df = Train.loc[(Train['PotentialFraud'] == 'Yes')]
Train_df = Train_df.rename (columns = {'Provider': 'provider', 'PotentialFraud': 'potential_fraud'})
Train_df.head()
# Out:
#     provider potential_fraud
# 1   PRV51003             Yes
# 3   PRV51005             Yes
# 13  PRV51021             Yes
# 25  PRV51037             Yes
# 37  PRV51052             Yes

# %%
Train_Inpatient_df = Train_Inpatient[['BeneID', 'Provider']]
Train_Inpatient_df = Train_Inpatient_df.rename (columns = {'BeneID': 'beneid', 'Provider': 'provider'})
Train_Inpatient_df
# Out:
#            beneid  provider
# 0       BENE11001  PRV55912
# 1       BENE11001  PRV55907
# 2       BENE11001  PRV56046
# 3       BENE11011  PRV52405
# 4       BENE11014  PRV56614
# ...           ...       ...
# 40469  BENE159167  PRV53671
# 40470  BENE159175  PRV54981
# 40471  BENE159177  PRV56588
# 40472  BENE159177  PRV56575
# 40473  BENE159188  PRV54765
#
# [40474 rows x 2 columns]

# %%
Train_Outpatient_df = Train_Outpatient[['BeneID', 'Provider']]
Train_Outpatient_df = Train_Outpatient_df.rename (columns = {'BeneID': 'beneid', 'Provider': 'provider'})
Train_Outpatient_df.head()
# Out:
#       beneid  provider
# 0  BENE11002  PRV56011
# 1  BENE11003  PRV57610
# 2  BENE11003  PRV57595
# 3  BENE11004  PRV56011
# 4  BENE11004  PRV56011

# %%
Train_Beneficiary_df = Train_Beneficiary[['BeneID', 'State', 'DOB']]
Train_Beneficiary_df = Train_Beneficiary_df.rename (columns = {'BeneID': 'beneid', 'State': 'state', 'DOB': 'dob'})
Train_Beneficiary_df.head()
# Out:
#       beneid  state         dob
# 0  BENE11001     39  1943-01-01
# 1  BENE11002     39  1936-09-01
# 2  BENE11003     52  1936-08-01
# 3  BENE11004     39  1922-07-01
# 4  BENE11005     24  1935-09-01

# %%
fraud_inpatient_provider_df = pd.merge(Train_Inpatient_df, Train_df, how='inner', on='provider')
fraud_inpatient_provider_df
# Out:
#            beneid  provider potential_fraud
# 0       BENE11001  PRV55912             Yes
# 1       BENE17521  PRV55912             Yes
# 2       BENE21718  PRV55912             Yes
# 3       BENE22934  PRV55912             Yes
# 4       BENE24402  PRV55912             Yes
# ...           ...       ...             ...
# 23397  BENE142565  PRV55514             Yes
# 23398  BENE105735  PRV56566             Yes
# 23399  BENE135136  PRV55852             Yes
# 23400  BENE135136  PRV55852             Yes
# 23401  BENE145679  PRV55852             Yes
#
# [23402 rows x 3 columns]

# %%
fraud_outpatient_provider_df = pd.merge(Train_Outpatient_df, Train_df, how='inner', on='provider')
fraud_outpatient_provider_df
# Out:
#             beneid  provider potential_fraud
# 0        BENE11002  PRV56011             Yes
# 1        BENE11004  PRV56011             Yes
# 2        BENE11004  PRV56011             Yes
# 3        BENE11004  PRV56011             Yes
# 4        BENE11004  PRV56011             Yes
# ...            ...       ...             ...
# 189389  BENE144674  PRV56012             Yes
# 189390  BENE158989  PRV56012             Yes
# 189391  BENE111157  PRV51119             Yes
# 189392  BENE119614  PRV55472             Yes
# 189393  BENE130881  PRV55472             Yes
#
# [189394 rows x 3 columns]

# %%
#connect to local database 
database_connection = "postgres:postgres@localhost:5432/postgres"
#sql_lite = "sqlite:///my_sqlite.db"
#engine = create_engine(sql_lite)
engine = create_engine(f'postgresql://{database_connection}')

# %% [markdown]
# Use pandas to load csv converted DataFrame into Database

# %%
#Train_df.to_sql(name='train', con=engine, if_exists='append', index=False)

# %%
#Train_Beneficiary_df.to_sql(name='train_beneficiary', con=engine, if_exists='append', index=False)

# %%
#Train_Inpatient_df.to_sql(name='train_inpatient', con=engine, if_exists='append', index=False)

# %%
#Train_Outpatient_df.to_sql(name='train_outpatient', con=engine, if_exists='append', index=False)

# %%
#fraud_outpatient_provider_df.to_sql(name='outpatient_provider_fraud', con=engine, if_exists='append', index=False)

# %%
#fraud_inpatient_provider_df.to_sql(name='inpatient_provider_fraud', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from train', con=engine)
# Out:
#      provider potential_fraud
# 0    PRV51003             Yes
# 1    PRV51005             Yes
# 2    PRV51021             Yes
# 3    PRV51037             Yes
# 4    PRV51052             Yes
# ..        ...             ...
# 501  PRV57642             Yes
# 502  PRV57667             Yes
# 503  PRV57672             Yes
# 504  PRV57697             Yes
# 505  PRV57709             Yes
#
# [506 rows x 2 columns]

# %%
pd.read_sql_query('select * from train_beneficiary', con=engine)
# Out:
#             beneid  state         dob
# 0        BENE11001     39  1943-01-01
# 1        BENE11002     39  1936-09-01
# 2        BENE11003     52  1936-08-01
# 3        BENE11004     39  1922-07-01
# 4        BENE11005     24  1935-09-01
# ...            ...    ...         ...
# 138551  BENE159194     39  1939-07-01
# 138552  BENE159195     49  1938-12-01
# 138553  BENE159196      6  1916-06-01
# 138554  BENE159197     16  1930-01-01
# 138555  BENE159198     21  1952-04-01
#
# [138556 rows x 3 columns]

# %%
pd.read_sql_query('select * from train_inpatient', con=engine)
# Out:
#            beneid  provider
# 0       BENE11001  PRV55912
# 1       BENE11001  PRV55907
# 2       BENE11001  PRV56046
# 3       BENE11011  PRV52405
# 4       BENE11014  PRV56614
# ...           ...       ...
# 40469  BENE159167  PRV53671
# 40470  BENE159175  PRV54981
# 40471  BENE159177  PRV56588
# 40472  BENE159177  PRV56575
# 40473  BENE159188  PRV54765
#
# [40474 rows x 2 columns]

# %%
pd.read_sql_query('select * from train_outpatient', con=engine)
# Out:
#             beneid  provider
# 0        BENE11002  PRV56011
# 1        BENE11003  PRV57610
# 2        BENE11003  PRV57595
# 3        BENE11004  PRV56011
# 4        BENE11004  PRV56011
# ...            ...       ...
# 517732  BENE159198  PRV53699
# 517733  BENE159198  PRV53702
# 517734  BENE159198  PRV53676
# 517735  BENE159198  PRV53689
# 517736  BENE159198  PRV53689
#
# [517737 rows x 2 columns]

# %%
outpatient_fraud_df = pd.read_sql_query("""SELECT b.beneid, b.state, o.provider, o.potential_fraud
                        FROM train_beneficiary as b
                        LEFT JOIN outpatient_provider_fraud as o
                        ON b.beneid = o.beneid;""", con=engine)
outpatient_fraud_df.head()
# Out:
#       beneid  state  provider potential_fraud
# 0  BENE11004     39  PRV56011             Yes
# 1  BENE11004     39  PRV56011             Yes
# 2  BENE11004     39  PRV56011             Yes
# 3  BENE11004     39  PRV56011             Yes
# 4  BENE11004     39  PRV56011             Yes

# %%
inpatient_fraud_df = pd.read_sql_query("""SELECT b.beneid, b.state, i.provider, i.potential_fraud
                        FROM train_beneficiary as b
                        LEFT JOIN inpatient_provider_fraud as i
                        ON b.beneid = i.beneid
                        WHERE i.potential_fraud = 'Yes';""", con=engine)
inpatient_fraud_df.head()
# Out:
#       beneid  state  provider potential_fraud
# 0  BENE11001     39  PRV55912             Yes
# 1  BENE11017     31  PRV54986             Yes
# 2  BENE11028     38  PRV51148             Yes
# 3  BENE11034     34  PRV55193             Yes
# 4  BENE11034     34  PRV55215             Yes

# %%
outpatient_fraud_df.to_html('outpatient_provider_fraud.html')

# %%
inpatient_fraud_df.to_html('inpatient_provider_fraud.html')

# %%
#plot state with the highest number of fraud for outpatient services
outpatient_beneficiary_grouped = outpatient_fraud_df['state'].value_counts()
outpatient_beneficiary_grouped = outpatient_beneficiary_grouped.to_frame()
outpatient_beneficiary_grouped['Fraud Count Outpatient'] = outpatient_beneficiary_grouped['state']
outpatient_beneficiary_grouped['STATE'] = outpatient_beneficiary_grouped.index
outpatient_beneficiary_grouped = outpatient_beneficiary_grouped.drop(['state'], axis = 1)
outpatient_beneficiary_grouped = outpatient_beneficiary_grouped.head(20)
outpatient_beneficiary_grouped.plot(x ='STATE', y='Fraud Count Outpatient', kind = 'barh')

# %%
#plot state with the highest number of fraud for inpatient services
inpatient_beneficiary_grouped = inpatient_fraud_df['state'].value_counts()
inpatient_beneficiary_grouped = inpatient_beneficiary_grouped.to_frame()
inpatient_beneficiary_grouped['Fraud Count Inpatient'] = inpatient_beneficiary_grouped['state']
inpatient_beneficiary_grouped['STATE'] = inpatient_beneficiary_grouped.index
inpatient_beneficiary_grouped = inpatient_beneficiary_grouped.drop(['state'], axis = 1)
inpatient_beneficiary_grouped = inpatient_beneficiary_grouped.head(20)
inpatient_beneficiary_grouped.plot(x ='STATE', y='Fraud Count Inpatient', kind = 'barh', color = 'g')
